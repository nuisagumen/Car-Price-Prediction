# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# uploading a data set and checking if any of the values is missing
dataset = pd.read_csv('C:/Users/Anna/OneDrive/Desktop/Regression Project/Car-Price-Prediction/CarPrice_Assignment.csv')
dataset
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
dataset.isnull().values.any()
# Out:
# False

# %%
# splitting the data frame into features and what has to be predicted (price of the car)
X = dataset.drop(columns=['price', 'car_ID'])
y = dataset['price']

# %%
X
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
# Encoding the independent variables
from sklearn.preprocessing import OneHotEncoder

# Finding categorical items
categorical_columns = X.select_dtypes(include=['object']).columns.tolist()

# Initialize the OneHotEncoder and transform all the categorical columns at once
encoder = OneHotEncoder()
X_encoded = encoder.fit_transform(X[categorical_columns])

# Dropping the original columns from and adding the encoded columns (horizonatally)
X = X.drop(columns=categorical_columns)

# recording number of numerical columns to standardise them later
n_numerical = len(X.columns)
X.iloc[:, :n_numerical]

X_encoded = X_encoded.toarray()
X = np.concatenate((X, X_encoded), axis=1)

# %%
X
# Out:
# array([[  3. ,  88.6, 168.8, ...,   1. ,   0. ,   0. ],
#        [  3. ,  88.6, 168.8, ...,   1. ,   0. ,   0. ],
#        [  1. ,  94.5, 171.2, ...,   1. ,   0. ,   0. ],
#        ...,
#        [ -1. , 109.1, 188.8, ...,   1. ,   0. ,   0. ],
#        [ -1. , 109.1, 188.8, ...,   0. ,   0. ,   0. ],
#        [ -1. , 109.1, 188.8, ...,   1. ,   0. ,   0. ]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)

# %%
print(X_train)
# Out:
# [[  1.   99.2 178.5 ...   1.    0.    0. ]
#  [  1.   94.5 165.3 ...   0.    0.    0. ]
#  [  0.   97.  173.5 ...   1.    0.    0. ]
#  ...
#  [  3.   96.6 180.3 ...   1.    0.    0. ]
#  [  2.   93.3 157.3 ...   0.    0.    0. ]
#  [  0.   96.5 167.5 ...   0.    0.    0. ]]

# %%
print(y_train)
# Out:
# 106    18399.0
# 90      7099.0
# 147    10198.0
# 185     8195.0
# 95      7799.0
#         ...
# 133    12170.0
# 137    18620.0
# 72     35056.0
# 140     7603.0
# 37      7895.0
# Name: price, Length: 164, dtype: float64

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
# 163     8058.0
# 28      8921.0
# 16     41315.0
# 130     9295.0
# 116    17950.0
# 182     7775.0
# 27      8558.0
# 47     32250.0
# 58     15645.0
# 204    22625.0
# 138     5118.0
# Name: price, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
#sc_y = StandardScaler()

X_train[:,:n_numerical] = sc_x.fit_transform(X_train[:,:n_numerical])
#y_train = sc_y.fit_transform(y_train.values.reshape(-1, 1))


X_test[:,:n_numerical] = sc_x.transform(X_test[:,:n_numerical])
#y_test = sc_y.transform(y_test.values.reshape(-1, 1))
